# %%
import pandas as pd

# %%
data = pd.read_csv("client/files/questions.csv")

# %%
tmp = data.head(10)
tmp.to_csv('client/files/questions_test.csv', index=False)
tmp
# Out:
#    Unnamed: 0        Id  OwnerUserId          CreationDate ClosedDate  Score  \
# 0           0  34727970    5774394.0  2016-01-11T17:52:23Z        NaN     -1
# 1           1  38968720    6438706.0  2016-08-16T07:15:33Z        NaN     -1
# 2           2  17901840    1270645.0  2013-07-27T19:48:44Z        NaN      1
# 3           3  36911990     648896.0  2016-04-28T10:30:23Z        NaN      1
# 4           4   7900230     281014.0  2011-10-26T08:18:03Z        NaN      0
# 5           5  14774690    1021327.0  2013-02-08T14:26:02Z        NaN      0
# 6           6  36865550    6168629.0  2016-04-26T12:52:52Z        NaN      0
# 7           7   4653120     179736.0  2011-01-11T00:44:26Z        NaN      0
# 8           8  11584720      20654.0  2012-07-20T18:08:20Z        NaN      2
# 9           9  27829110     606371.0  2015-01-07T21:39:20Z        NaN      3
#
#                                                Title  \
# 0                         For-loop and object naming
# ...
